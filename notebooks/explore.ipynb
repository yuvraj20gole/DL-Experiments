# %% [markdown]
# # Titanic Dataset Exploration
#
# Quick sanity check for cleaning and feature engineering steps in the preprocessing pipeline.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(project_root / "src"))

from pipeline import TitanicPreprocessor, get_titanic_data

# %%
preprocessor = TitanicPreprocessor()

df = get_titanic_data(str(project_root / "data" / "raw" / "titanic.csv"))
df = preprocessor.clean(df)
df = preprocessor.feature_engineer(df)

df.head()

# %%
df.isnull().sum()
